# %%
import csv

# %%
# enrollments = []

# with open('enrollments.csv','rt', encoding="utf8") as yoyo:
#     reader = csv.reader(yoyo)
    
#     for row in reader:
#         print(row)

# %%
enrollments = []

with open('enrollments.csv','rt') as yoyo:
    reader = csv.DictReader(yoyo)
    
    for row in reader:
        enrollments.append(row)
#         print(row)

        
# reader.close()

# %%
enrollments[0]
# Out:
# {'account_key': '448',
#  'status': 'canceled',
#  'join_date': '2014-11-10',
#  'cancel_date': '2015-01-14',
#  'days_to_cancel': '65',
#  'is_udacity': 'True',
#  'is_canceled': 'True'}

# %%
with open('enrollments.csv', 'rt') as f:
    reader = csv.DictReader(f)
    enrollments = list(reader)

# %%
enrollments[0]
# Out:
# {'account_key': '448',
#  'status': 'canceled',
#  'join_date': '2014-11-10',
#  'cancel_date': '2015-01-14',
#  'days_to_cancel': '65',
#  'is_udacity': 'True',
#  'is_canceled': 'True'}

# %% [markdown]
# ## reading csv files

# %%
def read_csv(filename):
    with open(filename, 'rt') as f:
        reader = csv.DictReader(f)
        return list(reader)

# %%
daily_engagement = read_csv('daily_engagement.csv')

# %%
daily_engagement[0]
# Out:
# {'acct': '0',
#  'utc_date': '2015-01-09',
#  'num_courses_visited': '1.0',
#  'total_minutes_visited': '11.6793745',
#  'lessons_completed': '0.0',
#  'projects_completed': '0.0'}

# %%
project_submissions = read_csv('project_submissions.csv')

# %%
project_submissions[0]
# Out:
# {'creation_date': '2015-01-14',
#  'completion_date': '2015-01-16',
#  'assigned_rating': 'UNGRADED',
#  'account_key': '256',
#  'lesson_key': '3176718735',
#  'processing_state': 'EVALUATED'}

# %% [markdown]
# ## parsing date and integers

# %%
from datetime import datetime as dt

# this takes a string as input and returns python datetime object as output.
# if string is empty it returns None.
def parse_date(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%Y-%m-%d')
    
#takes a string, returns integer

def parse_maybe_int(n):
    if n == '':
        return None
    else:
        return int(n)

# %%
print(parse_date("2015-10-20"))
# Out:
# 2015-10-20 00:00:00

# %%
parse_maybe_int("13")
# Out:
# 13

# %%
for enrollment in enrollments:
    enrollment['join_date'] = parse_date(enrollment['join_date'])
    enrollment['cancel_date'] = parse_date(enrollment['cancel_date'])
    enrollment['days_to_cancel'] = parse_maybe_int(enrollment['days_to_cancel'])
    enrollment['is_udacity'] = enrollment['is_udacity'] == 'True'
    enrollment['is_canceled'] = enrollment['is_canceled'] == 'True'

# %%
enrollments[0]
# Out:
# {'account_key': '448',
#  'status': 'canceled',
#  'join_date': datetime.datetime(2014, 11, 10, 0, 0),
#  'cancel_date': datetime.datetime(2015, 1, 14, 0, 0),
#  'days_to_cancel': 65,
#  'is_udacity': True,
#  'is_canceled': True}

# %%
for x in daily_engagement:
    x['num_courses_visited'] = int(float(x['num_courses_visited']))
    x['total_minutes_visited'] = float(x['total_minutes_visited'])
    x['lessons_completed'] = int(float(x['lessons_completed']))
    x['projects_completed'] = int(float(x['projects_completed']))
    x['utc_date'] = parse_date(x['utc_date'])

# %%
daily_engagement[0]
# Out:
# {'acct': '0',
#  'utc_date': datetime.datetime(2015, 1, 9, 0, 0),
#  'num_courses_visited': 1,
#  'total_minutes_visited': 11.6793745,
#  'lessons_completed': 0,
#  'projects_completed': 0}

# %%
for y in project_submissions:
    y['creation_date'] = parse_date(y['creation_date'])
    y['completion_date'] = parse_date(y['completion_date'])

# %%
project_submissions[0]
# Out:
# {'creation_date': datetime.datetime(2015, 1, 14, 0, 0),
#  'completion_date': datetime.datetime(2015, 1, 16, 0, 0),
#  'assigned_rating': 'UNGRADED',
#  'account_key': '256',
#  'lesson_key': '3176718735',
#  'processing_state': 'EVALUATED'}

# %% [markdown]
# ***changing the column name to generalise things***

# %%
for a_record in daily_engagement:
    a_record['account_key'] = a_record['acct']
    del[a_record['acct']]

# %% [markdown]
# ***to get unique no of rows***

# %%
def get_unique_students(data):
    unique_students= set()
    for record in data:
        unique_students.add(record['account_key'])
    return unique_students

# %%
enrollment_num_rows = len(enrollments) 
enrollment_num_unique_students = len(get_unique_students(enrollments))


engagement_num_rows = len(daily_engagement)
engagement_num_unique_students = len(get_unique_students(daily_engagement))  


submission_num_rows = len(project_submissions)
submission_num_unique_students = len(get_unique_students(project_submissions))

# %%
daily_engagement[0]['account_key']
# Out:
# '0'

# %%
for student in enrollments:
    if student['account_key'] not in get_unique_students(daily_engagement):
        print(student)
        break
# Out:
# {'account_key': '1219', 'status': 'canceled', 'join_date': datetime.datetime(2014, 11, 12, 0, 0), 'cancel_date': datetime.datetime(2014, 11, 12, 0, 0), 'days_to_cancel': 0, 'is_udacity': False, 'is_canceled': True}

# %%
# for enrollment in enrollments:
#     student = enrollment['account_key']
#     if student not in unique_engagement_students:
#         print(enrollment)
#         break

unique_engagement_students = get_unique_students(daily_engagement)

# %%
num_problem_students = 0
for enrollment in enrollments:
    student = enrollment['account_key']
    if (student not in unique_engagement_students and 
            enrollment['join_date'] != enrollment['cancel_date']):
        print(enrollment)
        num_problem_students += 1

num_problem_students
# Out:
# {'account_key': '1304', 'status': 'canceled', 'join_date': datetime.datetime(2015, 1, 10, 0, 0), 'cancel_date': datetime.datetime(2015, 3, 10, 0, 0), 'days_to_cancel': 59, 'is_udacity': True, 'is_canceled': True}
# {'account_key': '1304', 'status': 'canceled', 'join_date': datetime.datetime(2015, 3, 10, 0, 0), 'cancel_date': datetime.datetime(2015, 6, 17, 0, 0), 'days_to_cancel': 99, 'is_udacity': True, 'is_canceled': True}
# {'account_key': '1101', 'status': 'current', 'join_date': datetime.datetime(2015, 2, 25, 0, 0), 'cancel_date': None, 'days_to_cancel': None, 'is_udacity': True, 'is_canceled': False}
# 3

# %%
udacity_test_accounts = set()

for enrollment in enrollments:
    if enrollment['is_udacity']:
        udacity_test_accounts.add(enrollment['account_key'])
len(udacity_test_accounts)
# Out:
# 6

# %%
# remove udacity accounts
non_udacity_enrollments = set()
unique_enrollment = get_unique_students(enrollments)

def reomve_udacity_accounts(data):
    non_udacity_data = []
    for data_point in data:
        if data_point['account_key'] not in udacity_test_accounts:
            non_udacity_data.append(data_point)
    return non_udacity_data

# %%
non_udacity_enrollments = reomve_udacity_accounts(enrollments)
non_udacity_engagement = reomve_udacity_accounts(daily_engagement)
non_udacity_submissions = reomve_udacity_accounts(project_submissions)

print(len(non_udacity_enrollments))
print(len(non_udacity_engagement))
print(len(non_udacity_submissions))
# Out:
# 1622
# 135656
# 3634

# %%
paid_students = {}

# %%
for a_student in enrollments:
    if (not a_student['is_canceled'] and (a_student['days_to_cancel'] == None or a_student['days_to_cancel']>7)):
        paid_students = dict.fromkeys(a_student['account_key'], a_student['join_date'])

# %%
paid_students
# Out:
# {'6': datetime.datetime(2015, 8, 23, 0, 0),
#  '8': datetime.datetime(2015, 8, 23, 0, 0)}

# %%
paid_students = {}
for enrollment in non_udacity_enrollments:
    if (not enrollment['is_canceled'] or
            enrollment['days_to_cancel'] > 7):
        account_key = enrollment['account_key']
        enrollment_date = enrollment['join_date']
        if (account_key not in paid_students or
                enrollment_date > paid_students[account_key]):
            paid_students[account_key] = enrollment_date
len(paid_students)
# Out:
# 995

# %%
def within_one_week(join_date, engagement_date):
    time_delta = engagement_date - join_date
    return time_delta.days < 7 and time_delta.days >=0

# %%
def remove_free_trial_cancels(data):
    new_data = []
    for data_point in data:
        if data_point['account_key'] in paid_students:
            new_data.append(data_point)
    return new_data

# %%
paid_enrollments = remove_free_trial_cancels(non_udacity_enrollments)
paid_engagement = remove_free_trial_cancels(non_udacity_engagement)
paid_submissions = remove_free_trial_cancels(non_udacity_submissions)

print(len(paid_enrollments))
print(len(paid_engagement))
print(len(paid_submissions))
# Out:
# 1293
# 134549
# 3618

# %%
for engagement_record in paid_engagement:
    if engagement_record['num_courses_visited'] > 0:
        engagement_record['has_visited'] = 1
    else:
        engagement_record['has_visited'] = 0

# %%
paid_engagement_in_first_week = []
for engagement_record in paid_engagement:
    account_key = engagement_record['account_key']
    join_date = paid_students[account_key]
    engagement_record_date = engagement_record['utc_date']

    if within_one_week(join_date, engagement_record_date):
         paid_engagement_in_first_week.append(engagement_record)

len(paid_engagement_in_first_week)
# Out:
# 6919

# %% [markdown]
# # Group Data

# %%
from collections import defaultdict

def group_data(data, key_name):
    grouped_data = defaultdict(list)

    for data_point in data:
        key = data_point[key_name]
        grouped_data[key].append(data_point)
    return grouped_data

engagement_by_account = group_data(paid_engagement_in_first_week,
                                   'account_key')

# len(engagement_by_account)

# %%
from collections import defaultdict

engagement_by_account = defaultdict(list)

for engagement_record in paid_engagement_in_first_week:
    account_key = engagement_record['account_key']
    engagement_by_account[account_key].append(engagement_record)
    
# len(engagement_by_account)

# %% [markdown]
# # Sum Grouped Items

# %%
def sum_grouped_items(data, field_name):
    summed_data = {}
    
    for key, data_point in data.items():
        total = 0
        for data_value in data_point:
            total += data_value[field_name]
            summed_data[key] = total
    return summed_data
    
    
total_minutes_by_account = sum_grouped_items(engagement_by_account,
                                             'total_minutes_visited')   

# len(total_minutes_by_account)

# %%
total_minutes_by_account = {}

for account_key, engagement_for_student in engagement_by_account.items():
    total_minutes = 0
    for engagement_record in engagement_for_student:
        total_minutes += engagement_record['total_minutes_visited']
        total_minutes_by_account[account_key] = total_minutes

        
# len(total_minutes_by_account)

# %%
total_minutes = list(total_minutes_by_account.values())

# print(total_minutes)


import numpy as np 

np.mean(total_minutes)
# Out:
# 306.70832675342825

# %% [markdown]
# # Describing Data

# %%
import numpy as np

def describe_data(data):
    print('Mean:', np.mean(data))
    print('Standard deviation:', np.std(data))
    print('Minimum:', np.min(data))
    print('Maximum:', np.max(data))

# describe_data(total_minutes)
describe_data(total_minutes)
# Out:
# Mean: 306.70832675342825
# Standard deviation: 412.99693340852957
# Minimum: 0.0
# Maximum: 3564.7332644989997

# %%
student_with_max_minutes = None
max_minutes = 0

for student, total_minutes in total_minutes_by_account.items():
    if total_minutes > max_minutes:
        max_minutes = total_minutes
        student_with_max_minutes = student
        
max_minutes
# Out:
# 3564.7332644989997

# %%
for engagement_record in paid_engagement_in_first_week:
    if engagement_record['account_key'] == student_with_max_minutes:
        print(engagement_record)
# Out:
# {'utc_date': datetime.datetime(2015, 7, 9, 0, 0), 'num_courses_visited': 4, 'total_minutes_visited': 850.519339666, 'lessons_completed': 4, 'projects_completed': 0, 'account_key': '163', 'has_visited': 1}
# {'utc_date': datetime.datetime(2015, 7, 10, 0, 0), 'num_courses_visited': 6, 'total_minutes_visited': 872.633923334, 'lessons_completed': 6, 'projects_completed': 0, 'account_key': '163', 'has_visited': 1}
# {'utc_date': datetime.datetime(2015, 7, 11, 0, 0), 'num_courses_visited': 2, 'total_minutes_visited': 777.018903666, 'lessons_completed': 6, 'projects_completed': 0, 'account_key': '163', 'has_visited': 1}
# {'utc_date': datetime.datetime(2015, 7, 12, 0, 0), 'num_courses_visited': 1, 'total_minutes_visited': 294.568774, 'lessons_completed': 2, 'projects_completed': 0, 'account_key': '163', 'has_visited': 1}
# {'utc_date': datetime.datetime(2015, 7, 13, 0, 0), 'num_courses_visited': 3, 'total_minutes_visited': 471.2139785, 'lessons_completed': 1, 'projects_completed': 0, 'account_key': '163', 'has_visited': 1}
# {'utc_date': datetime.datetime(2015, 7, 14, 0, 0), 'num_courses_visited': 2, 'total_minutes_visited': 298.778345333, 'lessons_completed': 1, 'projects_completed': 0, 'account_key': '163', 'has_visited': 1}
# {'utc_date': datetime.datetime(2015, 7, 15, 0, 0), 'num_courses_visited': 0, 'total_minutes_visited': 0.0, 'lessons_completed': 0, 'projects_completed': 0, 'account_key': '163', 'has_visited': 0}

# %%
total_lessons_completed_by_account = {}

for account_key, engagement_for_student in engagement_by_account.items():
    total_lessons_completed = 0
    for engagement_record in engagement_for_student:
        total_lessons_completed += engagement_record['lessons_completed']
        total_lessons_completed_by_account[account_key] = total_lessons_completed

# %%
total_lessons = list(total_lessons_completed_by_account.values())

# %%
print('Mean:', np.mean(total_lessons))
print('Standard deviation:', np.std(total_lessons))
print('Minimum:', np.min(total_lessons))
print('Maximum:', np.max(total_lessons))
# Out:
# Mean: 1.636180904522613
# Standard deviation: 3.002561299829423
# Minimum: 0
# Maximum: 36

# %%
# data_by_account = group_data(paid_engagement_in_first_week,
#                                                  'account_key')

lessons_completeed_by_account = sum_grouped_items(engagement_by_account, 'lessons_completed')

describe_data(list(lessons_completed_by_account.values()))
# Out:
# Mean: 960.1849246231155
# Standard deviation: 496.37035530134074
# Minimum: 1
# Maximum: 1628

# %%
days_visited_by_account = sum_grouped_items(engagement_by_account, 'has_visited')

describe_data(list(days_visited_by_account.values()))
# Out:
# Mean: 2.8673366834170855
# Standard deviation: 2.2551980029196814
# Minimum: 0
# Maximum: 7

# %%
# passing_engagement
# non_passing_engagement

# %%
paid_submissions[0]
# Out:
# {'creation_date': datetime.datetime(2015, 1, 14, 0, 0),
#  'completion_date': datetime.datetime(2015, 1, 16, 0, 0),
#  'assigned_rating': 'UNGRADED',
#  'account_key': '256',
#  'lesson_key': '3176718735',
#  'processing_state': 'EVALUATED'}

# %%
subway_project_keys = ['746169184','3176718735']

# %%
pass_subway_projects = set()

for paid_submission in paid_submissions:
    project = paid_submission['lesson_key']
    rating = paid_submission['assigned_rating']
    if project in subway_project_keys and (rating == 'PASSED' or rating == 'DISTINCTION'):
        pass_subway_projects.add(paid_submission['account_key'])
        
len(pass_subway_projects)
# Out:
# 647

# %%
passing_engagement = []
non_passing_engagement = []

for engagement_record in paid_engagement_in_first_week:
    if engagement_record['account_key'] in pass_subway_projects:
        passing_engagement.append(engagement_record)
    else:
        non_passing_engagement.append(engagement_record)
        
print(len(passing_engagement))
print(len(non_passing_engagement))
# Out:
# 4527
# 2392

# %%
passing_engagement
# Out:
# [{'utc_date': datetime.datetime(2015, 1, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 11.6793745,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '0',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 10, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 37.2848873333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '0',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 11, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 53.6337463333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '0',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 33.4892696667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '0',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 64.7796776667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '0',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 14, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 151.617576833,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '0',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 142.395963833,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '0',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 6, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 9.640248,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '1',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 7, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '1',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '1',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '1',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '1',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '1',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 8.93613666667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '1',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 6, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '2',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '2',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '2',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '2',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '2',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '2',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '2',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '3',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '3',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '3',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '3',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '3',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '3',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '3',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '4',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '4',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '4',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 33.3214046667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '4',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '4',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '4',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 18, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '4',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 1, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 59.7267188333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 1, 9, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 103.568613833,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 80.1818903333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 36.2465346667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 50.034099,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '5',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 5, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 5.63057216667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '6',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 6, 6, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 76.5443475,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '6',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 6, 7, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 134.276672167,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '6',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 6, 8, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 203.849392833,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '6',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 6, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 196.479387,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '6',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 6, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 163.6741795,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '6',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 6, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '6',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 42.4996946667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '7',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '7',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 14, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 27.8152431667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '7',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '7',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '7',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '7',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 18, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 33.8889506667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '7',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 6, 0, 0),
#   'num_courses_visited': 3,
#   'total_minutes_visited': 152.185322,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '8',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 93.6641945,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '8',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 8, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 136.103098667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '8',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 32.9946208333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '8',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 352.344563333,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '8',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 184.993429333,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '8',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 12, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 36.8284131667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '8',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 8, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 54.8963445,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '9',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 295.804237667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '9',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '9',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 1, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '9',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 1, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '9',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 1, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 36.2090455,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '9',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 14, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 61.5617565,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '9',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '10',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 16.2460585,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '10',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 12, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 108.982875667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '10',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '10',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '10',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '10',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 4.89454416667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '10',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 24, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '11',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 25, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '11',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 26, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '11',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 27, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '11',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 28, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '11',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 29, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '11',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 30, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '11',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '12',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 11, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 166.3987555,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '12',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '12',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 13.0731533333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '12',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '12',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '12',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '12',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 1, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 79.4525436667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '13',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 2, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 512.965277,
#   'lessons_completed': 4,
#   'projects_completed': 0,
#   'account_key': '13',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 3, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 201.952520833,
#   'lessons_completed': 3,
#   'projects_completed': 0,
#   'account_key': '13',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 4, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 98.1097856667,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '13',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 5, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '13',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 6, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 47.894827,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '13',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 73.0084428333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '13',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 6, 3, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '14',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 4, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '14',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 5, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 65.6221875,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '14',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 6, 6, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '14',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 7, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '14',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '14',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '14',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 4, 0, 0),
#   'num_courses_visited': 4,
#   'total_minutes_visited': 172.709897334,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '15',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 3, 5, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 108.647330667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '15',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 3, 6, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 128.439285667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '15',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 3, 7, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '15',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '15',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 186.486383667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '15',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 3, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 387.092143,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '15',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 13, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 86.2670026667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '16',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '16',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '16',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 32.8532978333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '16',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '16',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 18, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '16',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 19, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '16',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '17',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '17',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 13, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 230.602350667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '17',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 14, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 4.89734083333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '17',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '17',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '17',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '17',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 11, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 87.1443163333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 12, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 33.370874,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 16.5147731667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 18.106194,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '18',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 6, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 7, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '19',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 11, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 86.5932986667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '20',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 253.409778,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '20',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 3.33416266667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '20',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '20',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 77.3180143333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '20',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 27.2837241667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '20',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '20',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 7, 17, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 333.773288166,
#   'lessons_completed': 4,
#   'projects_completed': 0,
#   'account_key': '21',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 7, 18, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 2.355257,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '21',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 7, 19, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 45.3878131667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '21',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 7, 20, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 2.50203766667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '21',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 7, 21, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 244.166696167,
#   'lessons_completed': 3,
#   'projects_completed': 0,
#   'account_key': '21',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 7, 22, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 49.3370568333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '21',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 7, 23, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 253.581542167,
#   'lessons_completed': 3,
#   'projects_completed': 0,
#   'account_key': '21',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 3, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 141.781845833,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '22',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 4, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 279.564017834,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '22',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 5, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 64.7746043333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '22',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 6, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 140.968281333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '22',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 30.1164841667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '22',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '22',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '22',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 10, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 70.513244,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '23',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 11, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 242.2342925,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '23',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 12, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 278.59787,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '23',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 13, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 385.771906167,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '23',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 14, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 111.180808333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '23',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 15, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 417.944309,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '23',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 16, 0, 0),
#   'num_courses_visited': 3,
#   'total_minutes_visited': 85.0803843334,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '23',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 12, 3, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '24',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 12, 4, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '24',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 12, 5, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '24',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 12, 6, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '24',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 12, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 217.707439667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '24',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 12, 8, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 284.554388,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '24',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 12, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 440.9262895,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '24',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 18, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '25',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 106.192694,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '26',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '26',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 96.8780855,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '26',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '26',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '26',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '26',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 17, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 227.730896333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '26',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 3.62017833333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '27',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 12, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 509.9254555,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '27',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 258.607945667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '27',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 14, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 722.138305833,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '27',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 84.8293413333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '27',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 5, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '27',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 5, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '27',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 1, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '28',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 1, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '28',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 1, 14, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 253.946815167,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '28',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '28',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 1, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 108.633035333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '28',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 17, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 177.399657167,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '28',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 18, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 226.276808,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '28',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 7, 16, 0, 0),
#   'num_courses_visited': 4,
#   'total_minutes_visited': 124.663766,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '29',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 7, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '29',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 7, 18, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '29',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 7, 19, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 209.67847,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '29',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 7, 20, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 103.9791075,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '29',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 7, 21, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 65.7623505,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '29',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 7, 22, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 52.1069093333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '29',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '30',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '30',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '30',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '30',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '30',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 56.8616045,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '30',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 12.7962306667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '30',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 3, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 15, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 16, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '31',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 1, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '32',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 1, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
# ...
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '133',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 19.9584945,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '133',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 6, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 3.0929055,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '133',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 6, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '133',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '133',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 6, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '133',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 5, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 10.1936145,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '134',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 6, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 419.114083667,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '134',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 90.9420196667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '134',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 8, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 55.3872981667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '134',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 31.4932595,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '134',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 291.053310333,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '134',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 118.919899333,
#   'lessons_completed': 2,
#   'projects_completed': 0,
#   'account_key': '134',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 14, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 101.208822333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '135',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 15, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 170.0036165,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '135',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 115.457630667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '135',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 17, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '135',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 18, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 207.759223667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '135',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 11, 19, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '135',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 11, 20, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 18.8274783333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '135',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '136',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '136',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '136',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '136',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '136',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '136',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 14, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 34.1685658333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '136',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 12, 6, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 559.012065333,
#   'lessons_completed': 3,
#   'projects_completed': 0,
#   'account_key': '137',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 12, 7, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 71.6231086667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '137',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2014, 12, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '137',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 12, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '137',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 12, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '137',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 12, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '137',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2014, 12, 12, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 65.6123305,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '137',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '138',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '138',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '138',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 11, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '138',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '138',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 4, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 90.3995656667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '138',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 4, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '138',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 6, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '139',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 7, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '139',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 8, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '139',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '139',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 10, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '139',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 86.4587005,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '139',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 3, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '139',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 1, 14, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 79.4930525,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '140',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 15, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 282.2645835,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '140',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 16, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 536.993184833,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '140',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 17, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 461.840850167,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '140',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 18, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 205.673807,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '140',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 19, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 403.5470465,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '140',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 1, 20, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 80.3031506667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '140',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 3, 7, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 144.208581333,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '141',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 3, 8, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 325.739279333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '141',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 3, 9, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 7.52177466667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '141',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 3, 10, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 6.81155533333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '141',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 3, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 20.0521448333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '141',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 3, 12, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '141',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 3, 13, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 40.6593231667,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '141',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 8, 19, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '142',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 8, 20, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '142',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 8, 21, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 180.873946167,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '142',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 8, 22, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '142',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 8, 23, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '142',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 8, 24, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 20.3442766667,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '142',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 8, 25, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '142',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 9, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '143',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 10, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 134.203557167,
#   'lessons_completed': 1,
#   'projects_completed': 0,
#   'account_key': '143',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 11, 0, 0),
#   'num_courses_visited': 1,
#   'total_minutes_visited': 53.7316928333,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '143',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 12, 0, 0),
#   'num_courses_visited': 2,
#   'total_minutes_visited': 217.0876175,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '143',
#   'has_visited': 1},
#  {'utc_date': datetime.datetime(2015, 2, 13, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '143',
#   'has_visited': 0},
#  {'utc_date': datetime.datetime(2015, 2, 14, 0, 0),
#   'num_courses_visited': 0,
#   'total_minutes_visited': 0.0,
#   'lessons_completed': 0,
#   'projects_completed': 0,
#   'account_key': '143',
#   'has_visited': 0},
#  ...]

# %%
passing_students_minutes_spent = []
passing_students_lessons_completed = []


for record in passing_engagement_by_account:
    passing_students_minutes_spent.append(record['total_minutes_visited'])
    passing_students_lessons_completed.append(record['lessons_completed'])
